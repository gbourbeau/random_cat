# %% [markdown]
# # Using _random_cat_

# %% [markdown]
# ### Import and run package

# %%
from random_cat import random_cat
random_cat()
# Out:
# True

# %% [markdown]
# ### Photo opened in new window:

# %% [markdown]
# ![Screen%20Shot%202022-12-14%20at%204.26.22%20PM.png](attachment:Screen%20Shot%202022-12-14%20at%204.26.22%20PM.png)
